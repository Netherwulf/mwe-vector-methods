# %%
import ast
import math
import os

import conllu
import pandas as pd

# %% [markdown]
# <h4>Preprocess data and save to CSV</h4>

# %%
dir_path = os.path.join('..', 'storage', 'parseme', 'pl', 'raw_data')
filename = 'dev.cupt'

filepath = os.path.join(dir_path, filename)

# %%
with open(filepath, "r", encoding="utf-8") as f:
    sentence = next(conllu.parse_incr(f))
    tok = sentence[0]
    column_names = ['sent_id'] + list(tok.keys())
    
df = pd.DataFrame(columns = column_names)
    
with open(filepath, "r", encoding="utf-8") as f:
    sent_id = 0
    for sentence in conllu.parse_incr(f):
        sentence_rows = [{'sent_id': sent_id,
                          'id' : tok['id'],
                          'form': tok['form'],
                          'lemma': tok['lemma'],
                          'upos': tok['upos'],
                          'xpos': tok['xpos'],
                          'feats': tok['feats'],
                          'head': tok['head'],
                          'deprel': tok['deprel'],
                          'deps': tok['deps'],
                          'misc': tok['misc'],
                          'parseme:mwe': tok['parseme:mwe']} for tok in sentence]

        df = df.append(sentence_rows, ignore_index=True)

        sent_id += 1

df
# Out:
#       sent_id  id        form       lemma   upos  \
# 0           0   1  Szczególna  szczególny    ADJ
# 1           0   2       uwaga       uwaga   NOUN
# 2           0   3          ma        mieć   VERB
# 3           0   4         być         być   VERB
# 4           0   5  poświęcona   poświęcić    ADJ
# ...       ...  ..         ...         ...    ...
# 23945    1424  30          na          na    ADP
# 23946    1424  31      zawsze      zawsze    ADV
# 23947    1424  32        jego          on   PRON
# 23948    1424  33   tajemnicą   tajemnica   NOUN
# 23949    1424  34           .           .  PUNCT
#
#                                   xpos  \
# 0                     adj:sg:nom:f:pos
# 1                       subst:sg:nom:f
# 2                    fin:sg:ter:imperf
# 3                           inf:imperf
# 4               ppas:sg:nom:f:perf:aff
# ...                                ...
# 23945                         prep:acc
# 23946                              adv
# 23947  ppron3:sg:gen:m1:ter:akc:npraep
# 23948                  subst:sg:inst:f
# 23949                           interp
#
#                                                    feats head      deprel  \
# 0      {'Case': 'Nom', 'Degree': 'Pos', 'Gender': 'Fe...    2        amod
# 1      {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Si...    3       nsubj
# 2      {'Aspect': 'Imp', 'Mood': 'Ind', 'Number': 'Si...    0        root
# 3      {'Aspect': 'Imp', 'VerbForm': 'Inf', 'Voice': ...    3       xcomp
# 4      {'Aspect': 'Perf', 'Case': 'Nom', 'Gender': 'F...    4       xcomp
# ...                                                  ...  ...         ...
# 23945                                {'AdpType': 'Prep'}   31        case
# 23946                                {'PronType': 'Tot'}   28      advmod
# 23947  {'Animacy': 'Hum', 'Case': 'Gen', 'Gender': 'M...   33        nmod
# 23948  {'Case': 'Ins', 'Gender': 'Fem', 'Number': 'Si...   28  xcomp:pred
# 23949                              {'PunctType': 'Peri'}   28       punct
#
#                      deps                  misc parseme:mwe
# 0                    None                  None           *
# 1                    None                  None           *
# 2                    None                  None           *
# 3                    None                  None           *
# 4                    None                  None           *
# ...                   ...                   ...         ...
# 23945        [(case, 31)]       {'Case': 'Acc'}           *
# 23946      [(advmod, 28)]                  None           *
# 23947        [(nmod, 33)]                  None           *
# 23948  [(xcomp:pred, 28)]  {'SpaceAfter': 'No'}           *
# 23949       [(punct, 28)]                  None           *
#
# [23950 rows x 12 columns]

# %%
# save dataframe to csv
df.to_csv(os.path.join(dir_path, f'{filename.split(".")[0]}_df.tsv'), sep='\t', index=False)

# %%
# get tokens related to MWE
df[df['parseme:mwe'] != '*']
# Out:
#       sent_id  id           form        lemma  upos                   xpos  \
# 8           0   9  doprowadzenie  doprowadzić  NOUN  ger:sg:nom:n:perf:aff
# 9           0  10             do           do   ADP               prep:gen
# 12          0  13        chrztów      chrzest  NOUN        subst:pl:gen:m3
# 43          1  14         cieszą      cieszyć  VERB      fin:pl:ter:imperf
# 44          1  15            się          się  PRON                    qub
# ...       ...  ..            ...          ...   ...                    ...
# 73727    4388   4        relację      relacja  NOUN         subst:sg:acc:f
# 73735    4389   5       udzielić     udzielić  VERB               inf:perf
# 73738    4389   8            rad         rada  NOUN         subst:pl:gen:f
# 73744    4389  13          śmiał        śmiać  VERB     praet:sg:m1:imperf
# 73746    4389  15            się          się  PRON                   part
#
#                                                    feats  head     deprel  \
# 8      {'Aspect': 'Perf', 'Case': 'Nom', 'Gender': 'N...     2      nsubj
# 9                                    {'AdpType': 'Prep'}    12       case
# 12     {'Animacy': 'Inan', 'Case': 'Gen', 'Gender': '...    12   nmod:arg
# 43     {'Aspect': 'Imp', 'Mood': 'Ind', 'Number': 'Pl...     8  acl:relcl
# 44                  {'PronType': 'Prs', 'Reflex': 'Yes'}    14    expl:pv
# ...                                                  ...   ...        ...
# 73727  {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Si...     2        obj
# 73735  {'Aspect': 'Perf', 'VerbForm': 'Inf', 'Voice':...   2.0      xcomp
# 73738  {'Case': 'Gen', 'Gender': 'Fem', 'Number': 'Pl...   5.0        obj
# 73744  {'Animacy': 'Hum', 'Aspect': 'Imp', 'Gender': ...  10.0      ccomp
# 73746               {'PronType': 'Prs', 'Reflex': 'Yes'}  13.0    expl:pv
#
#                    deps                  misc  parseme:mwe
# 8          [(nsubj, 2)]                  None  1:LVC.cause
# 9          [(case, 12)]       {'Case': 'Gen'}            1
# 12     [(nmod:arg, 12)]                  None            1
# 43                 None                  None        1:IRV
# 44                 None                  None            1
# ...                 ...                   ...          ...
# 73727        [(obj, 2)]                  None            1
# 73735      [(xcomp, 2)]                  None   1:LVC.full
# 73738        [(obj, 5)]  {'SpaceAfter': 'No'}            1
# 73744     [(ccomp, 10)]                  None        2:IRV
# 73746   [(expl:pv, 13)]                  None            2
#
# [2826 rows x 12 columns]

# %%
# get number of MWE instances
df[(df['parseme:mwe'] != '*') & (df['parseme:mwe'].str.len() > 1)]
# Out:
#       sent_id  id           form        lemma  upos                   xpos  \
# 8           0   9  doprowadzenie  doprowadzić  NOUN  ger:sg:nom:n:perf:aff
# 43          1  14         cieszą      cieszyć  VERB      fin:pl:ter:imperf
# 144         6  27      uśmiechał    uśmiechać  VERB     praet:sg:m1:imperf
# 149         7   1     Przychodzą  przychodzić  VERB      fin:pl:ter:imperf
# 304        15  10           brać         brać  VERB             inf:imperf
# ...       ...  ..            ...          ...   ...                    ...
# 73645    4384  28         chlubi      chlubić  VERB      fin:sg:ter:imperf
# 73689    4386  17            był          być  VERB     praet:sg:m1:imperf
# 73725    4388   2           zdał         zdać  VERB       praet:sg:m1:perf
# 73735    4389   5       udzielić     udzielić  VERB               inf:perf
# 73744    4389  13          śmiał        śmiać  VERB     praet:sg:m1:imperf
#
#                                                    feats  head  \
# 8      {'Aspect': 'Perf', 'Case': 'Nom', 'Gender': 'N...     2
# 43     {'Aspect': 'Imp', 'Mood': 'Ind', 'Number': 'Pl...     8
# 144    {'Animacy': 'Hum', 'Aspect': 'Imp', 'Gender': ...     2
# 149    {'Aspect': 'Imp', 'Mood': 'Ind', 'Number': 'Pl...     0
# 304    {'Aspect': 'Imp', 'VerbForm': 'Inf', 'Voice': ...     9
# ...                                                  ...   ...
# 73645  {'Aspect': 'Imp', 'Mood': 'Ind', 'Number': 'Si...    25
# 73689  {'Animacy': 'Hum', 'Aspect': 'Imp', 'Gender': ...   0.0
# 73725  {'Animacy': 'Hum', 'Aspect': 'Perf', 'Gender':...     0
# 73735  {'Aspect': 'Perf', 'VerbForm': 'Inf', 'Voice':...   2.0
# 73744  {'Animacy': 'Hum', 'Aspect': 'Imp', 'Gender': ...  10.0
#
#                  deprel                      deps  misc  parseme:mwe
# 8                 nsubj              [(nsubj, 2)]  None  1:LVC.cause
# 43            acl:relcl                      None  None        1:IRV
# 144                conj    [(root, 0), (conj, 2)]  None        1:IRV
# 149                root               [(root, 0)]  None        1:VID
# 304               xcomp              [(xcomp, 9)]  None   1:LVC.full
# ...                 ...                       ...   ...          ...
# 73645  parataxis:insert  [(parataxis:insert, 25)]  None        2:IRV
# 73689              root               [(root, 0)]  None        1:VID
# 73725              root               [(root, 0)]  None   1:LVC.full
# 73735             xcomp              [(xcomp, 2)]  None   1:LVC.full
# 73744             ccomp             [(ccomp, 10)]  None        2:IRV
#
# [1340 rows x 12 columns]

# %%
# get number of MWE instances which occur with other MWEs in the same sentence
temp_df = df[(df['parseme:mwe'] != '*') & (df['parseme:mwe'].str.len() > 1)]

temp_df[temp_df.duplicated(subset='sent_id')]
# Out:
#       sent_id  id             form           lemma  upos  \
# 1291       75  13      wprowadzono      wprowadzić  VERB
# 4315      268  24        dokonanie       dokonanie  NOUN
# 4705      286  41            umowy           umowa  NOUN
# 4805      294   5  samookreśleniem  samookreślenie  NOUN
# 4847      297  22        pochłonął       pochłonąć  VERB
# ...       ...  ..              ...             ...   ...
# 71629    4263  24             mamy            mieć  VERB
# 72645    4323  17        wchodząca        wchodzić   ADJ
# 73288    4366  19             mają            mieć  VERB
# 73645    4384  28           chlubi         chlubić  VERB
# 73744    4389  13            śmiał           śmiać  VERB
#
#                            xpos  \
# 1291                  imps:perf
# 4315      ger:sg:acc:n:perf:aff
# 4705             subst:sg:gen:f
# 4805            subst:sg:inst:n
# 4847           praet:sg:m3:perf
# ...                         ...
# 71629         fin:pl:pri:imperf
# 72645  pact:sg:nom:f:imperf:aff
# 73288         fin:pl:ter:imperf
# 73645         fin:sg:ter:imperf
# 73744        praet:sg:m1:imperf
#
#                                                    feats  head  \
# 1291   {'Aspect': 'Perf', 'Mood': 'Ind', 'Person': '0...     7
# 4315   {'Aspect': 'Perf', 'Case': 'Acc', 'Gender': 'N...    21
# 4705   {'Case': 'Gen', 'Gender': 'Fem', 'Number': 'Si...    40
# 4805   {'Case': 'Ins', 'Gender': 'Neut', 'Number': 'S...     3
# 4847   {'Animacy': 'Inan', 'Aspect': 'Perf', 'Gender'...    16
# ...                                                  ...   ...
# 71629  {'Aspect': 'Imp', 'Mood': 'Ind', 'Number': 'Pl...    12
# 72645  {'Aspect': 'Imp', 'Case': 'Nom', 'Gender': 'Fe...    21
# 73288  {'Aspect': 'Imp', 'Mood': 'Ind', 'Number': 'Pl...     3
# 73645  {'Aspect': 'Imp', 'Mood': 'Ind', 'Number': 'Si...    25
# 73744  {'Animacy': 'Hum', 'Aspect': 'Imp', 'Gender': ...  10.0
#
#                  deprel                      deps  misc  parseme:mwe
# 1291          acl:relcl          [(acl:relcl, 7)]  None  2:LVC.cause
# 4315               conj                      None  None   2:LVC.full
# 4705           nmod:arg          [(nmod:arg, 40)]  None   2:LVC.full
# 4805               nmod                      None  None        2:IRV
# 4847          acl:relcl         [(acl:relcl, 16)]  None   2:LVC.full
# ...                 ...                       ...   ...          ...
# 71629             ccomp             [(ccomp, 12)]  None        2:VID
# 72645               acl                      None  None        2:VID
# 73288              conj                      None  None   2:LVC.full
# 73645  parataxis:insert  [(parataxis:insert, 25)]  None        2:IRV
# 73744             ccomp             [(ccomp, 10)]  None        2:IRV
#
# [174 rows x 12 columns]

# %% [markdown]
# <h4>Read train data CSV</h4>

# %%
# read test dataframe from TSV file
df_train = pd.read_csv(os.path.join(dir_path, 'train_df.tsv'), sep='\t')

df_train
# Out:
#         sent_id id         form     lemma   upos                   xpos  \
# 0             0  1     Większym      duży    ADJ     adj:sg:inst:m3:com
# 1             0  2    problemem   problem   NOUN       subst:sg:inst:m3
# 2             0  3       będzie       być    AUX   bedzie:sg:ter:imperf
# 3             0  4  znalezienie   znaleźć   NOUN  ger:sg:nom:n:perf:aff
# 4             0  5    zawodnika  zawodnik  PROPN        subst:sg:gen:m1
# ...         ... ..          ...       ...    ...                    ...
# 298432    17730  1       Gorąco    gorąco    ADV                adv:pos
# 298433    17730  2         więc      więc  CCONJ                   conj
# 298434    17730  3      polecam   polecać   VERB      fin:sg:pri:imperf
# 298435    17730  4       kartkę    kartka   NOUN         subst:sg:acc:f
# 298436    17730  5            .         .  PUNCT                 interp
#
#                                                     feats  head  deprel deps  \
# 0       {'Animacy': 'Inan', 'Case': 'Ins', 'Degree': '...   2.0    amod  NaN
# 1       {'Animacy': 'Inan', 'Case': 'Ins', 'Gender': '...   0.0    root  NaN
# 2       {'Aspect': 'Imp', 'Mood': 'Ind', 'Number': 'Si...   2.0     cop  NaN
# 3       {'Aspect': 'Perf', 'Case': 'Nom', 'Gender': 'N...   2.0   nsubj  NaN
# 4       {'Animacy': 'Hum', 'Case': 'Gen', 'Gender': 'M...   4.0     obj  NaN
# ...                                                   ...   ...     ...  ...
# 298432                                  {'Degree': 'Pos'}   3.0  advmod  NaN
# 298433                                                NaN   1.0   fixed  NaN
# 298434  {'Aspect': 'Imp', 'Mood': 'Ind', 'Number': 'Si...   0.0    root  NaN
# 298435  {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Si...   3.0     obj  NaN
# 298436                              {'PunctType': 'Peri'}   3.0   punct  NaN
#
#                         misc parseme:mwe
# 0                        NaN           *
# 1                        NaN           *
# 2                        NaN           *
# 3                        NaN           *
# 4       {'SpaceAfter': 'No'}           *
# ...                      ...         ...
# 298432                   NaN           *
# 298433                   NaN           *
# 298434                   NaN           *
# 298435  {'SpaceAfter': 'No'}           *
# 298436                   NaN           *
#
# [298437 rows x 12 columns]

# %%
# get DataFrame and count of potential incorrect MWEs
# df_non_mwe = df_test[df_test['parseme:mwe'] == '*']


# PoS types, wchich appear at least 50 times in train set
# verb + pron (zaimek)
# verb + noun
# adj + noun
# pron + verb
# verb + adp (przyimek)
# adj + pron
# noun + verb
# noun + noun
# noun + adj
# adp + noun
# noun + pron
df = pd.read_csv(os.path.join('..', 'storage', 'parseme', 'pl', 'preprocessed_data', 'test', 'test_df.tsv'), sep='\t')
correct_mwe_list = pd.read_csv(os.path.join('..', 'storage', 'parseme', 'pl', 'preprocessed_data', 'test', 'parseme_test_correct_mwes.tsv'), sep='\t')['full_mwe_lemma'].tolist()
incorr_mwe_df = pd.DataFrame(columns=['type', 'first_word', 'first_word_lemma', 'first_word_id',
                                      'second_word', 'second_word_lemma', 'second_word_id',
                                      'full_mwe', 'full_mwe_lemma', 'sentence'])

correct_pos = ['VERB+PRON', 'VERB+NOUN', 'ADJ+NOUN', 'VERB+ADP', 'ADJ+PRON', 
               'NOUN+VERB', 'NOUN+NOUN', 'NOUN+ADJ', 'ADP+NOUN', 'NOUN+PRON']

mwe_count = 0
mwe_count_dict = {}

for sent_id in df['sent_id'].unique():
    pos_list = df[df['sent_id'] == sent_id]['upos'].tolist()
    idx_list = df[df['sent_id'] == sent_id]['id'].tolist()
    form_list = df[df['sent_id'] == sent_id]['form'].tolist()
    lemma_list = df[df['sent_id'] == sent_id]['lemma'].tolist()
    mwe_tag_list = df[df['sent_id'] == sent_id]['parseme:mwe'].tolist()
    deprel_list = df[df['sent_id'] == sent_id]['deprel'].tolist()
    deps_list = [ast.literal_eval(elem) if type(elem) == str else [] for elem in df[df['sent_id'] == sent_id]['deps'].tolist()]
    sentence = ' '.join([str(word) for word in form_list])
    # print(f'Ids of words: {df[df["sent_id"] == sent_id]["id"].tolist()}')
    
    for pos_ind, pos in enumerate(pos_list[:-1]):
        first_pos = pos
        second_pos = pos_list[pos_ind + 1]
        mwe_pos = f'{first_pos}+{second_pos}'
        
        first_word_deps = [elem[1] for elem in deps_list[pos_ind]]
        second_word_deps = [elem[1] for elem in deps_list[pos_ind + 1]]
        
        if (mwe_pos in correct_pos and 
            mwe_tag_list[pos_ind] == '*' and 
            mwe_tag_list[pos_ind + 1 ] == '*' and 
            (int(idx_list[pos_ind]) in second_word_deps or int(idx_list[pos_ind + 1]) in first_word_deps) and
            ' '.join([lemma_list[pos_ind], lemma_list[pos_ind + 1]]) not in correct_mwe_list):
            mwe_count += 1
            
            # print every 1000th MWE
            # if mwe_count % 1000 == 0:
            #     print(f"{mwe_pos}\t{idx_list[pos_ind]}\t{form_list[pos_ind]}\t{deps_list[pos_ind]}\t{idx_list[pos_ind+1]}\t{form_list[pos_ind + 1]}\t{deps_list[pos_ind+1]}")
            
            # add MWE count to the dictionary
            if mwe_pos not in mwe_count_dict.keys():
                mwe_count_dict[mwe_pos] = 1
                
            else:
                mwe_count_dict[mwe_pos] += 1
                
            # append MWE to DataFrame
            incorr_mwe_df = incorr_mwe_df.append({'type': mwe_pos, 
                                                  'first_word': form_list[pos_ind], 
                                                  'first_word_lemma': lemma_list[pos_ind],
                                                  'first_word_id': pos_ind,
                                                  'second_word': form_list[pos_ind + 1],
                                                  'second_word_lemma': lemma_list[pos_ind + 1],
                                                  'second_word_id': int(pos_ind) + 1,
                                                  'full_mwe': str(form_list[pos_ind]) + ' ' + str(form_list[pos_ind + 1]),
                                                  'full_mwe_lemma': str(lemma_list[pos_ind]) + ' ' + str(lemma_list[pos_ind + 1]),
                                                  'sentence': sentence}, 
                                                 ignore_index=True)

# save DataFrame to TSV
incorr_mwe_df.to_csv(os.path.join('..', 'storage', 'parseme', 'pl', 'preprocessed_data', 'test', 'parseme_test_incorrect_mwes.tsv'), sep='\t', index=False)
            
print(f'MWE count: {mwe_count}')
mwe_count_dict
# Out:
# MWE count: 7114
# {'ADJ+NOUN': 1575,
#  'NOUN+NOUN': 1112,
#  'NOUN+ADJ': 825,
#  'ADP+NOUN': 1920,
#  'VERB+NOUN': 673,
#  'NOUN+VERB': 525,
#  'VERB+PRON': 445,
#  'VERB+ADP': 10,
#  'ADJ+PRON': 19,
#  'NOUN+PRON': 10}

# %%
incorr_mwe_df = pd.read_csv(os.path.join('..', 'storage', 'parseme', 'pl', 'preprocessed_data', 'test', 'parseme_test_incorrect_mwes.tsv'), sep='\t')
incorr_mwe_df
# Out:
#            type   first_word first_word_lemma  first_word_id   second_word  \
# 0      ADJ+NOUN      Głównym           główny              0      zadaniem
# 1     NOUN+NOUN     zadaniem          zadanie              1  Uniwersytetu
# 2      ADJ+NOUN  maksymalnej       maksymalny             10        liczby
# 3      ADJ+NOUN        całej             cały             20       kultury
# 4      NOUN+ADJ      kultury          kultura             21    japońskiej
# ...         ...          ...              ...            ...           ...
# 7109   NOUN+ADJ      Książek          książka             10    Zakazanych
# 7110   NOUN+ADJ      rubryka          rubryka             21    oceniająca
# 7111   ADJ+NOUN   oceniająca          oceniać             22         filmy
# 7112   NOUN+ADJ        filmy             film             23   wyświetlane
# 7113   ADP+NOUN            z                z              4       podróży
#
#      second_word_lemma  second_word_id               full_mwe  \
# 0              zadanie               1       Głównym zadaniem
# 1          uniwersytet               2  zadaniem Uniwersytetu
# 2               liczba              11     maksymalnej liczby
# 3              kultura              21          całej kultury
# 4             japoński              22     kultury japońskiej
# ...                ...             ...                    ...
# 7109          zakazany              11     Książek Zakazanych
# 7110           oceniać              22     rubryka oceniająca
# 7111              film              23       oceniająca filmy
# 7112        wyświetlać              24      filmy wyświetlane
# 7113            podróż               5              z podróży
#
#            full_mwe_lemma                                           sentence
# 0          główny zadanie  Głównym zadaniem Uniwersytetu Nanzan jest więc...
# 1     zadanie uniwersytet  Głównym zadaniem Uniwersytetu Nanzan jest więc...
# 2       maksymalny liczba  Głównym zadaniem Uniwersytetu Nanzan jest więc...
# 3            cały kultura  Głównym zadaniem Uniwersytetu Nanzan jest więc...
# 4        kultura japoński  Głównym zadaniem Uniwersytetu Nanzan jest więc...
# ...                   ...                                                ...
# 7109     książka zakazany  Jedyną pozostałością z czasów , kiedy wydawany...
# 7110      rubryka oceniać  Jedyną pozostałością z czasów , kiedy wydawany...
# 7111         oceniać film  Jedyną pozostałością z czasów , kiedy wydawany...
# 7112      film wyświetlać  Jedyną pozostałością z czasów , kiedy wydawany...
# 7113             z podróż            Jerzy zdał obszerną relację z podróży .
#
# [7114 rows x 10 columns]

# %%
[ast.literal_eval(elem) for elem in df_train[df_train['sent_id'] == 5]['deps'].tolist()]
# Out:
# [[('root', 0)],
#  [('advmod:emph', 1)],
#  [('punct', 11)],
#  [('mark', 11)],
#  [('case', 6)],
#  [('obl', 11)],
#  [('case', 8)],
#  [('nmod', 6)],
#  [('nsubj', 11)],
#  [('nmod', 9)],
#  [('ccomp', 1)],
#  [('xcomp', 11)],
#  [('obj', 12)],
#  [('case', 16), ('case', 18)],
#  [('amod:flat', 16)],
#  [('obl', 12)],
#  [('cc', 18)],
#  [('obl', 12), ('conj', 16)],
#  [('punct', 29)],
#  [('advmod', 29)],
#  [('punct', 23)],
#  [('nmod:poss', 23)],
#  [('parataxis:insert', 29)],
#  [('punct', 23)],
#  [('nsubj', 29)],
#  [('cop', 29)],
#  [('case', 29)],
#  [('fixed', 27)],
#  [('acl:relcl', 16), ('acl:relcl', 18)],
#  [('case', 31)],
#  [('obl', 29)],
#  [('amod', 31)],
#  [('punct', 1)]]

# %%
# get number of MWE instances
df_train[(df_train['parseme:mwe'] != '*') & (df_train['parseme:mwe'].str.len() > 1)]
# Out:
#         sent_id  id        form      lemma  upos                      xpos  \
# 177           8  11      wpadam     wpadać  VERB         fin:sg:pri:imperf
# 184           9   3    znajduje  znajdować  VERB         fin:sg:ter:imperf
# 301          14  39     pełniła     pełnić  VERB         praet:sg:f:imperf
# 340          16  14  trzymająca    trzymać   ADJ  pact:sg:nom:f:imperf:aff
# 404          18  54         się        się  PRON                      part
# ...         ...  ..         ...        ...   ...                       ...
# 298272    17718   9       czują       czuć  VERB         fin:pl:ter:imperf
# 298285    17719   5     ankiety    ankieta  NOUN            subst:sg:gen:f
# 298298    17720   2       Widzę    widzieć  VERB         fin:sg:pri:imperf
# 298337    17723   9     starała     starać  VERB         praet:sg:f:imperf
# 298370    17724  20     zgodził    zgodzić  VERB          praet:sg:m1:perf
#
#                                                     feats  head       deprel  \
# 177     {'Aspect': 'Imp', 'Mood': 'Ind', 'Number': 'Si...   0.0         root
# 184     {'Aspect': 'Imp', 'Mood': 'Ind', 'Number': 'Si...   0.0         root
# 301     {'Aspect': 'Imp', 'Gender': 'Fem', 'Mood': 'In...  13.0         conj
# 340     {'Aspect': 'Imp', 'Case': 'Nom', 'Gender': 'Fe...  13.0          acl
# 404                  {'PronType': 'Prs', 'Reflex': 'Yes'}  55.0      expl:pv
# ...                                                   ...   ...          ...
# 298272  {'Aspect': 'Imp', 'Mood': 'Ind', 'Number': 'Pl...   1.0         conj
# 298285  {'Case': 'Gen', 'Gender': 'Fem', 'Number': 'Si...   4.0         nmod
# 298298  {'Aspect': 'Imp', 'Mood': 'Ind', 'Number': 'Si...   0.0         root
# 298337  {'Aspect': 'Imp', 'Gender': 'Fem', 'Mood': 'In...   6.0  ccomp:cleft
# 298370  {'Animacy': 'Hum', 'Aspect': 'Perf', 'Gender':...  11.0         conj
#
#                                deps misc parseme:mwe
# 177                   [('root', 0)]  NaN  1:LVC.full
# 184                             NaN  NaN       1:IRV
# 301     [('conj', 5), ('conj', 13)]  NaN  1:LVC.full
# 340                   [('acl', 13)]  NaN  1:LVC.full
# 404               [('expl:pv', 55)]  NaN       1:IRV
# ...                             ...  ...         ...
# 298272   [('root', 0), ('conj', 1)]  NaN       1:IRV
# 298285                          NaN  NaN  1:LVC.full
# 298298                          NaN  NaN       1:VID
# 298337         [('ccomp:cleft', 6)]  NaN       1:IRV
# 298370                          NaN  NaN       1:IRV
#
# [5380 rows x 12 columns]

# %%
# check if there are any MWEs without VERB
df_train[(df_train['parseme:mwe'] != '*')]
nonverb_mwe_count = 0

for sent_id in df_train['sent_id'].unique():
    pos_list = df_train[df_train['sent_id'] == sent_id]['upos'].tolist()
    mwe_tag_list = df_train[df_train['sent_id'] == sent_id]['parseme:mwe'].tolist()
    
    for pos_ind, pos in enumerate(pos_list[:-1]):
        if (pos != 'VERB' and pos_list[pos_ind + 1] != 'VERB') and mwe_tag_list[pos_ind] != '*' and mwe_tag_list[pos_ind + 1] != '*':
            nonverb_mwe_count += 1
            
nonverb_mwe_count
# Out:
# 1026

# %%
# get dictionary and dataframe containing PoS tag counts for CORRECT MWEs
def get_dict_key(mwe_dict, mwe_type_id, last_key=False):
    mwe_type_count = len([key for key in mwe_dict.keys() if key[0] == mwe_type_id])

    if last_key and mwe_type_count > 0:
        mwe_type_count -= 1
        
    return f'{mwe_type_id}-{mwe_type_count}'

df_train = pd.read_csv(os.path.join('..', 'storage', 'parseme', 'pl', 'preprocessed_data', 'test', 'test_df.tsv'), sep='\t')
df_correct_mwe = pd.DataFrame(columns=['type', 'first_word', 'first_word_lemma', 'first_word_id',
                                      'second_word', 'second_word_lemma', 'second_word_id',
                                      'full_mwe', 'full_mwe_lemma', 'sentence'])
mwe_count_dict = {}

for sent_id in df_train['sent_id'].unique():
    pos_list = df_train[df_train['sent_id'] == sent_id]['upos'].tolist()
    mwe_tag_list = df_train[df_train['sent_id'] == sent_id]['parseme:mwe'].tolist()
    idx_list = df_train[df_train['sent_id'] == sent_id]['id'].tolist()
    form_list = df_train[df_train['sent_id'] == sent_id]['form'].tolist()
    lemma_list = df_train[df_train['sent_id'] == sent_id]['lemma'].tolist()
    sentence = ' '.join([str(word) for word in form_list])
    # mwe_component_ind = [False for _ in range(len(pos_list))]
    
#     for pos_ind, pos in enumerate(pos_list[:-1]):
#         if mwe_component_ind[pos_ind]:
#             continue

#         if ((pos_ind == 0 or mwe_tag_list[pos_ind - 1] == '*') and
#             mwe_tag_list[pos_ind] != '*' and
#             mwe_tag_list[pos_ind + 1] != '*' and
#             (pos_ind + 1 == len(pos_list) - 1 or mwe_tag_list[pos_ind + 2] == '*')):
            
    mwe = ''
    mwe_pos = ''
    mwe_ind_list = []
    mwe_dict = {}
    for ind, mwe_tag in enumerate(mwe_tag_list):
        
        # sprawdzaj po kolei tagi tak jak w przypadku MWE dłuższych niż 2 - jeżeli trafisz na * to nie dodajesz go do MWE, 
        # ale dodajesz składowe do MWE aż nie trafisz na token dłuższy niż 1 znak
        # checks MWE tags until it gets tag longer than 1 char - if it gets it then it is considered as the new MWE
        # if not longer than 1 char then if it is equal to * then it is not added to the MWE components list
        # if it is not equal to * then add it as the next component of MWE
        
        if len(mwe_tag) == 1 and mwe_tag != '*':
            mwe_dict[get_dict_key(mwe_dict, mwe_tag, last_key=True)][0] += f' {form_list[ind].lower()}'
            mwe_dict[get_dict_key(mwe_dict, mwe_tag, last_key=True)][1] += f'+{pos_list[ind]}'
            mwe_dict[get_dict_key(mwe_dict, mwe_tag, last_key=True)][2].append(ind)

        if len(mwe_tag) != 1:
            for related_mwe in  mwe_tag.split(';'):
                if len(related_mwe) == 1:
                    mwe_dict[get_dict_key(mwe_dict, related_mwe, last_key=True)][0] += f' {form_list[ind].lower()}'
                    mwe_dict[get_dict_key(mwe_dict, related_mwe, last_key=True)][1] += f'+{pos_list[ind]}'
                    mwe_dict[get_dict_key(mwe_dict, related_mwe, last_key=True)][2].append(ind)
                
                if len(related_mwe) > 1:
                    new_mwe_key = get_dict_key(mwe_dict, related_mwe[0], last_key=False)

                    mwe = form_list[ind]
                    mwe_pos = pos_list[ind]
                    mwe_ind_list = [ind]

                    mwe_dict[new_mwe_key] = [mwe, mwe_pos, mwe_ind_list]
            
            
        if ind == len(mwe_tag_list) - 1:
            
            for mwe_key in sorted(mwe_dict.keys(), key=lambda x:x.lower()):
                
                mwe = mwe_dict[mwe_key][0]
                mwe_pos = mwe_dict[mwe_key][1]
                mwe_ind_list = mwe_dict[mwe_key][2]
                
                if len(mwe_ind_list) == 2 and int(mwe_ind_list[1]) - int(mwe_ind_list[0]) == 1:
                    df_correct_mwe = df_correct_mwe.append({'type': mwe_pos, 
                                                          'first_word': form_list[mwe_ind_list[0]], 
                                                          'first_word_lemma': lemma_list[mwe_ind_list[0]],
                                                          'first_word_id': mwe_ind_list[0],
                                                          'second_word': form_list[mwe_ind_list[1]],
                                                          'second_word_lemma': lemma_list[mwe_ind_list[1]],
                                                          'second_word_id': int(mwe_ind_list[1]),
                                                          'full_mwe': str(form_list[mwe_ind_list[0]]) + ' ' + str(form_list[mwe_ind_list[1]]),
                                                          'full_mwe_lemma': str(lemma_list[mwe_ind_list[0]]) + ' ' + str(lemma_list[mwe_ind_list[1]]),
                                                          'sentence': sentence}, 
                                                         ignore_index=True)

                    if mwe_pos not in mwe_count_dict.keys():
                        mwe_count_dict[mwe_pos] = 1

                    else:
                        mwe_count_dict[mwe_pos] += 1
            
# save DataFrame to TSV
# df_correct_mwe.to_csv('parseme_correct_mwes.tsv', sep='\t', index=False)
            
mwe_count_dict
df_correct_mwe
# Out:
#           type first_word first_word_lemma first_word_id second_word  \
# 0    VERB+PRON     cieszą          cieszyć            13         się
# 1    VERB+PRON  uśmiechał        uśmiechać            26         się
# 2    VERB+NOUN       brać             brać             9    kredytów
# 3    VERB+NOUN  rozdziera       rozdzierać            11       szaty
# 4    VERB+PRON     dzieje            dziać             2         się
# ..         ...        ...              ...           ...         ...
# 873   ADJ+NOUN     mające             mieć             7      szansę
# 874  VERB+PRON      wydał            wydać             4         się
# 875  VERB+NOUN      miały             mieć             6   problemów
# 876  VERB+PRON     nadaje          nadawać            15         się
# 877  VERB+PRON     chlubi          chlubić            27         się
#
#     second_word_lemma second_word_id         full_mwe    full_mwe_lemma  \
# 0                 się             14       cieszą się       cieszyć się
# 1                 się             27    uśmiechał się     uśmiechać się
# 2              kredyt             10    brać kredytów       brać kredyt
# 3               szata             12  rozdziera szaty  rozdzierać szata
# 4                 się              3       dzieje się         dziać się
# ..                ...            ...              ...               ...
# 873            szansa              8    mające szansę       mieć szansa
# 874               się              5        wydał się         wydać się
# 875           problem              7  miały problemów      mieć problem
# 876               się             16       nadaje się       nadawać się
# 877               się             28       chlubi się       chlubić się
#
#                                               sentence
# 0    Zagospodarowane zostaną tereny w pobliżu pomni...
# 1    Tamci podchwycili okrzyk , przestali tupać , p...
# 2    - Ale jak rozwijać produkcję , skoro nie warto...
# 3    Jak dotąd lewica nie ma nic konkretnego do zao...
# 4    W praktyce dzieje się tak w większości spraw r...
# ..                                                 ...
# 873  - To powinny być przecież ostatnie osoby mając...
# 874    Zatrzymali samochód , bo wydał się podejrzany .
# 875  Jednak wszystkie te ugrupowania nie będą miały...
# 876  Słusznie , bowiem nawet najwięksi apologeci ni...
# 877  Słusznie , bowiem nawet najwięksi apologeci ni...
#
# [878 rows x 10 columns]

# %%
df_correct_mwe.to_csv(os.path.join('..', 'storage', 'parseme', 'pl', 'preprocessed_data', 'test', 'parseme_test_correct_mwes.tsv'), sep='\t', index=False)

# %%
correct_mwe_count = sum([elem for elem in mwe_count_dict.values()])

correct_mwe_count
# Out:
# 4064

# %%
len(incorr_mwe_df['full_mwe'].unique().tolist())
# Out:
# 25758

# %%
# get dictionary containing PoS tag counts for INCORRECT MWEs
incorr_mwe_count_dict = {}

for pos_tag in incorr_mwe_df['type']:
    if pos_tag not in incorr_mwe_count_dict.keys():
        incorr_mwe_count_dict[pos_tag] = 1
    else:
        incorr_mwe_count_dict[pos_tag] += 1
        
incorr_mwe_count_dict
# Out:
# {'VERB+PRON': 1907,
#  'ADP+NOUN': 7968,
#  'NOUN+NOUN': 4485,
#  'ADJ+NOUN': 6152,
#  'NOUN+ADJ': 3407,
#  'VERB+NOUN': 2647,
#  'NOUN+VERB': 2260,
#  'VERB+ADP': 34,
#  'NOUN+PRON': 77,
#  'ADJ+PRON': 90}

# %%
incorrect_mwe_count = sum([1500 if elem > 1500 else elem for elem in incorr_mwe_count_dict.values()])

incorrect_mwe_count
# Out:
# 10701

# %%
undersampled_mwe_dict = {elem: count if count < 1500 else 1500 for elem, count in incorr_mwe_count_dict.items()}
undersampled_mwe_dict
# Out:
# {'VERB+PRON': 1500,
#  'ADP+NOUN': 1500,
#  'NOUN+NOUN': 1500,
#  'ADJ+NOUN': 1500,
#  'NOUN+ADJ': 1500,
#  'VERB+NOUN': 1500,
#  'NOUN+VERB': 1500,
#  'VERB+ADP': 34,
#  'NOUN+PRON': 77,
#  'ADJ+PRON': 90}
